# %%
# %autosave 3
# Out:
# Autosaving every 3 seconds

# %% [markdown]
# * x 输入
# * W 权重
# * b 偏差
# label y 预测 y_hat

# %% [markdown]
# # 1.神经网络
#
# ### 1.5 线性分界
#
# Wx + b = 0 W = (w1, w2) x=(x1,x2)
#
# ### 1.7 ![%E6%84%9F%E7%9F%A5%E5%99%A8.png](attachment:%E6%84%9F%E7%9F%A5%E5%99%A8.png)
