# %%
# %autosave 3
# Out:
# Autosaving every 3 seconds

# %% [markdown]
# # 1.神经网络
#
# ### 1.5 线性分界
#
# Wx + b = 0 W = (w1, w2) x=(x1,x2)

# %% [markdown]
# # 3.卷积神经网络CNN
# > Convolutional Neural Networks

# %% [raw]
# 三顿饭
# 你好

# %% [markdown]
# ![e0dbdb38864fbab8ecf0f5ade2280cf1.png](attachment:e0dbdb38864fbab8ecf0f5ade2280cf1.png)# 手动阀 ss
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
